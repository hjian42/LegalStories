# %% [markdown]
# ## Inter-rater Agreement
# - E1 stands for Eric and E2 stands for Robert, our two legal experts
# - We compute the inter-rater agreement between two experts and between each expert and GPT-4

# %%
import numpy as np
import pandas as pd

def cohen_kappa(a: np.int32, b: np.int32) -> float:
    assert a.shape == b.shape
    po = (a == b).astype(np.float32).mean()
    categories = sorted(set(list(np.concatenate((a, b), axis=0))))
    mp = {}
    for i, c in enumerate(categories):
        mp[c] = i
    k = len(mp)
    sa = np.zeros(shape=(k,), dtype=np.int32)
    sb = np.zeros(shape=(k,), dtype=np.int32)
    n = a.shape[0]
    for x, y in zip(list(a), list(b)):
        sa[mp[x]] += 1
        sb[mp[y]] += 1
    pe = 0
    for i in range(k):
        pe += (sa[i] / n) * (sb[i] / n)
    kappa = (po - pe) / (1.0 - pe)
    return kappa

# %%
def map_mc_choice(text):
    text = text.strip()
    choiceMap = {"(A)": 0, "(B)": 1, "(C)": 2, "(D)": 3, "A": 0, "B": 1, "C": 2, "D": 3}
    return choiceMap[text]

df_annos = pd.read_csv("./expert_annotations/expert_annotation_agreements.tsv", sep="\t")
for column_name in ['concept_question_E2', 'concept_question_E1',
                    'concept_question_GPT4', 'prediction_question_E2',
                    'prediction_question_E1', 'prediction_question_GPT4',
                    'limitation_question_E2', 'limitation_question_E1',
                    'limitation_question_GPT4']:
    df_annos['encoded_{}'.format(column_name)] = df_annos[column_name].apply(map_mc_choice)
    del df_annos[column_name]
df_annos
# Out:
#                                          concept condition  \
# 0                            Abstention_doctrine        E1
# 1   Constitutional_convention_(political_custom)        E1
# 2                            Unaccompanied_minor        E2
# 3                 Substantial_certainty_doctrine        E1
# 4                           Learned_intermediary        E1
# 5                Doctrine_of_foreign_equivalents        E2
# 6                       Prosecutorial_discretion        E1
# 7                              Safe_harbor_(law)        E2
# 8                          FTC_v._Dean_Foods_Co.        E1
# 9                        Volenti_non_fit_injuria        E2
# 10                            Plain_meaning_rule        E1
# 11                             Purcell_principle        E2
# 12              Presumption_(Catholic_canon_law)        E2
# 13                                    Wrongdoing        E2
# 14                     Remoteness_in_English_law        E2
# 15                           Pacta_sunt_servanda        E2
# 16                                Maxwellisation        E2
# 17                              Brady_disclosure        E1
# 18                                Undue_hardship        E1
# 19                          Commanding_precedent        E1
#
#     encoded_concept_question_E2  encoded_concept_question_E1  \
# 0                             2                            2
# 1                             1                            1
# 2                             2                            2
# 3                             1                            1
# 4                             1                            1
# 5                             1                            1
# 6                             1                            1
# 7                             1                            1
# 8                             1                            1
# 9                             1                            1
# 10                            1                            1
# 11                            2                            2
# 12                            1                            1
# 13                            2                            2
# 14                            2                            1
# 15                            1                            1
# 16                            1                            1
# 17                            1                            1
# 18                            1                            1
# 19                            1                            1
#
#     encoded_concept_question_GPT4  encoded_prediction_question_E2  \
# 0                               2                               2
# 1                               1                               2
# 2                               2                               1
# 3                               1                               3
# 4                               1                               1
# 5                               1                               2
# 6                               1                               1
# 7                               1                               1
# 8                               1                               1
# 9                               1                               0
# 10                              1                               1
# 11                              2                               1
# 12                              1                               3
# 13                              2                               1
# 14                              1                               0
# 15                              1                               2
# 16                              1                               1
# 17                              1                               1
# 18                              1                               1
# 19                              1                               3
#
#     encoded_prediction_question_E1  encoded_prediction_question_GPT4  \
# 0                                2                                 2
# 1                                2                                 2
# 2                                1                                 1
# 3                                1                                 1
# 4                                1                                 1
# 5                                2                                 2
# 6                                1                                 1
# 7                                1                                 1
# 8                                1                                 1
# 9                                0                                 0
# 10                               0                                 0
# 11                               0                                 0
# 12                               3                                 3
# 13                               1                                 1
# 14                               0                                 0
# 15                               1                                 2
# 16                               1                                 1
# 17                               1                                 1
# 18                               1                                 1
# 19                               3                                 3
#
#     encoded_limitation_question_E2  encoded_limitation_question_E1  \
# 0                                1                               0
# 1                                3                               3
# 2                                2                               2
# 3                                3                               3
# 4                                1                               0
# 5                                0                               0
# 6                                2                               2
# 7                                2                               2
# 8                                3                               3
# 9                                2                               2
# 10                               2                               2
# 11                               3                               3
# 12                               2                               2
# 13                               3                               3
# 14                               1                               1
# 15                               0                               0
# 16                               2                               2
# 17                               3                               3
# 18                               3                               3
# 19                               2                               2
#
#     encoded_limitation_question_GPT4
# 0                                  2
# 1                                  3
# 2                                  2
# 3                                  3
# 4                                  0
# 5                                  0
# 6                                  2
# 7                                  3
# 8                                  3
# 9                                  2
# 10                                 2
# 11                                 3
# 12                                 2
# 13                                 3
# 14                                 1
# 15                                 0
# 16                                 2
# 17                                 3
# 18                                 3
# 19                                 2

# %%
import itertools

for q_type in ['concept', 'prediction', 'limitation']:
    for p1, p2 in itertools.combinations(['E1', 'E2', 'GPT4'], 2):
        cohen_kappa_score = round(cohen_kappa(df_annos["encoded_{}_question_{}".format(q_type, p1)], df_annos["encoded_{}_question_{}".format(q_type, p2)]), 2)
        print(q_type, p1, p2, cohen_kappa_score)
# Out:
# concept E1 E2 0.86
# concept E1 GPT4 1.0
# concept E2 GPT4 0.86
# prediction E1 E2 0.68
# prediction E1 GPT4 0.92
# prediction E2 GPT4 0.77
# limitation E1 E2 0.86
# limitation E1 GPT4 0.85
# limitation E2 GPT4 0.78

# %% [markdown]
# ## Expert annotations on Questions
# - Experts are asked to answer the following three points for each generated question in the `comment` columns:
#     1. Does your answer agree with the suggested answer?
#     2. Is the suggested answer correct or wrong? Why?
#     3. What suggestions do you have to improve the question?

# %%
df_e1 = pd.read_csv("./expert_annotations/E1_annotations.tsv", sep="\t")
df_e1.head(3)
# Out:
#                                         concept concept_question  \
# 0                                           NaN      your answer
# 1                           Abstention_doctrine                C
# 2  Constitutional_convention_(political_custom)                B
#
#                                           Unnamed: 2 prediction_question  \
# 0                                           comments         your answer
# 1  (1) Yes.  (2) The suggested answer is correct....                   C
# 2  (1) Yes.  (2) The suggested answer is correct....                   C
#
#                                           Unnamed: 4 limitation_question  \
# 0                                           comments         your answer
# 1  (1) Yes.  (2) The suggested answer is correct....                   A
# 2  (1) Yes.  (2) The suggested answer is correct....                   D
#
#                                           Unnamed: 6 Concept Difficulty
# 0                                           comments                NaN
# 1  (1) No.  (2) Based on the definition and story...               Hard
# 2  (1) Yes.  (2) The suggested answer is correct....               Easy

# %%
df_e2 = pd.read_csv("./expert_annotations/E2_annotations.tsv", sep="\t")
df_e2.head(3)
# Out:
#                                         concept concept_question  \
# 0                                           NaN      your answer
# 1                           Abstention_doctrine                C
# 2  Constitutional_convention_(political_custom)                B
#
#                                           Unnamed: 2 prediction_question  \
# 0                                           comments         your answer
# 1  (1) Yes.  (2) The suggested answer is correct....                   C
# 2  (1) Yes.  (2) The suggested answer is correct....                   C
#
#                                           Unnamed: 4 limitation_question  \
# 0                                           comments         your answer
# 1  (1) Yes.  (2) The suggested answer is correct....                   B
# 2  (1) Yes.  (2) The suggested answer is correct....                   D
#
#                                           Unnamed: 6 Concept Difficulty
# 0                                           comments                NaN
# 1  (1) No.  (2) The suggested answer is correct. ...               Easy
# 2  (1) Yes.  (2) The suggested answer is correct....             Medium

# %%
df_final_answers = pd.read_csv("./expert_annotations/Final_answer_annotations.tsv", sep="\t")
df_final_answers.head(3)
# Out:
#                                         concept concept_question_answer  \
# 0                           Abstention_doctrine                       C
# 1  Constitutional_convention_(political_custom)                       B
# 2                           Unaccompanied_minor                       C
#
#   prediction_question_answer limitation_question_answer difficulty  q_id
# 0                          C                          C       hard     0
# 1                          C                          D     medium     1
# 2                          B                          C     medium     2

# %%
df_final_regenerated_question_20 = pd.read_csv("./expert_annotations/Final_regenerated_questions_20.tsv", sep="\t")
df_final_regenerated_question_20.head(3)
# Out:
#                                         concept  \
# 0                           Abstention_doctrine
# 1  Constitutional_convention_(political_custom)
# 2                           Unaccompanied_minor
#
#                               concept_full_name  \
# 0                           Abstention doctrine
# 1  Constitutional convention (political custom)
# 2                           Unaccompanied minor
#
#                                           intro_text  \
# 0  An abstention doctrine is any of several doctr...
# 1  A constitutional convention is an informal and...
# 2  An unaccompanied minor (sometimes "unaccompani...
#
#                                                story  \
# 0  Imagine a big family dinner where everyone has...
# 1  Imagine you're playing a game of soccer with y...
# 2  Imagine a young boy named Timmy. Timmy is only...
#
#                                            Q_concept  \
# 0  Question: What is the main purpose of the Abst...
# 1  Question: Which of the following best describe...
# 2  Question: Which of the following best describe...
#
#                                         Q_prediction  \
# 0  Question: In a hypothetical scenario, a large ...
# 1  Question: In the fictional country of Veridia,...
# 2  Question: In a hypothetical scenario, 12-year-...
#
#                                         Q_limitation
# 0  Question: What is a potential limitation or ex...
# 1  Question: What is a potential limitation or ex...
# 2  Question: According to the UN Committee on the...
